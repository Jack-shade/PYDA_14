# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Netology/PYDA_14/10_Pandas (продвинутый)/test_1.csv')

# %%
df.tail()
# Out:
#           Дата     Время  Входящие звонки  Исходящие КЦ  Выписка     АКЦ  \
# 27  28.10.2020  00:00:00             7895          6465     2457    3401
# 28  29.10.2020  00:00:00             7695          6478     2341    3287
# 29  30.10.2020  00:00:00             7483          5321     2685    3295
# 30  31.10.2020  00:00:00             4875          3235      221    2315
# 31      Всего:       NaN           224796        172327    57482  101747
#
#     zakaz.rcc  rekvizit.rcc  operator.rcc   Чат  Сайт + ОПТ  Сайт ОПТ     ВК  \
# 27       1185           216           175   253        3352       546    8.0
# 28       1169           202           175   212        3397       597   11.0
# 29       1014           161           217   256        2910       545   13.0
# 30        176            17            21   187        1921       210    7.0
# 31      29679          5044          4363  8378       92521     14225  288.0
#
# ...

# %%
df['Вх и Исх'] = df.apply(lambda x: x['Входящие звонки'] + x['Исходящие КЦ'], axis = 1)

# %%
df.head()
# Out:
#          Дата     Время  Входящие звонки  Исходящие КЦ  Выписка   АКЦ  \
# 0  01.10.2020  00:00:00             8384          6325     2607  3800
# 1  02.10.2020  00:00:00             8545          6659     2495  3853
# 2  03.10.2020  00:00:00             5443          3176      217  2623
# 3  04.10.2020  00:00:00             3987          2311        1  1971
# 4  05.10.2020  00:00:00             8641          6393     2444  3987
#
#    zakaz.rcc  rekvizit.rcc  operator.rcc  Чат  ...  Сайт ОПТ    ВК  Тлг  \
# 0       1247           236           207  307  ...       523  11.0   17
# 1       1110           165           186  320  ...       536  10.0   17
# 2        171            19            47  174  ...       204   5.0   14
# 3        143            36            23  195  ...       169   5.0   21
# 4       1341           220           156  350  ...       578  15.0   30
#
#    Viber  СМС  СПА  Сайт от АКЦ  Сайт от АКЦ (Простой)  Вопросы с сайта  \
# ...

# %%
df.to_excel('C:/Netology/PYDA_14/10_Pandas (продвинутый)/test_2.xlsx', index=False)
